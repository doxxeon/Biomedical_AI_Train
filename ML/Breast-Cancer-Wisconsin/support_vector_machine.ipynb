# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix

from sklearn.model_selection import KFold, cross_val_score, cross_val_predict

# %%
data = pd.read_csv('/Users/kimdohyeon/건양대학교병원_바이오헬스/Biomedical_AI_Train/ML/Breast-Cancer-Wisconsin/data.csv')
data.head()
# Out:
#          id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0    842302         M  ...                  0.11890          NaN
# 1    842517         M  ...                  0.08902          NaN
# 2  84300903         M  ...                  0.08758          NaN
# 3  84348301         M  ...                  0.17300          NaN
# 4  84358402         M  ...                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %% [markdown]
# 📌 필요 없는 데이터 제거 (첫 번째 열과 마지막 열)

# %%
data = data.drop(['Unnamed: 32', 'id'], axis=1)

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %% [markdown]
# 📌 열 정보
# - diagnosis: 진단 결과 (M=악성, B=양성)
# - radius_mean, texture_mean, perimeter_mean, area_mean, smoothness_mean, compactness_mean, concavity_mean, concave points_mean, symmetry_mean, fractal_dimension_mean: 종양 특성
# - ~_se: 표준편차
# - ~_worst: 특성의 최악값(가장 큰 값)

# %% [markdown]
# 📌 파이썬의 map() 함수를 통해 진단 결과를 0과 1로 분리

# %%
data['diagnosis'] = data['diagnosis'].map({"M":1, "B":0})

data
# Out:
#      diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 0            1        17.99  ...          0.4601                  0.11890
# 1            1        20.57  ...          0.2750                  0.08902
# 2            1        19.69  ...          0.3613                  0.08758
# 3            1        11.42  ...          0.6638                  0.17300
# 4            1        20.29  ...          0.2364                  0.07678
# ..         ...          ...  ...             ...                      ...
# 564          1        21.56  ...          0.2060                  0.07115
# 565          1        20.13  ...          0.2572                  0.06637
# 566          1        16.60  ...          0.2218                  0.07820
# 567          1        20.60  ...          0.4087                  0.12400
# 568          0         7.76  ...          0.2871                  0.07039
#
# [569 rows x 31 columns]

# %% [markdown]
# 📌 정규화 (0~1 사이 값으로 변환)

# %%
X = data.drop('diagnosis', axis=1)
y = data['diagnosis']

train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
scaler = StandardScaler()
train_X_scaled = scaler.fit_transform(train_X)
test_X_scaled = scaler.fit_transform(test_X)

# %% [markdown]
# 📌 SVM 구현 코드

# %%
svm_model = SVC(kernel='linear', probability=True)
svm_model.fit(train_X_scaled, train_y)
# Out:
# SVC(kernel='linear', probability=True)

# %%
y_pred = svm_model.predict(test_X_scaled)
y_pred_proba = svm_model.predict_proba(test_X_scaled)

pred_df = pd.DataFrame({
    'actual_class': test_y, 
    'predicted_class': y_pred,
    'probabilty_class_0': y_pred_proba[:,0], # malignant (악성)
    'probablity_class_1': y_pred_proba[:,1] # benign (양성)
})

pred_df.head(10)
# Out:
#      actual_class  predicted_class  probabilty_class_0  probablity_class_1
# 512             1                1            0.027420            0.972580
# 457             0                0            0.954799            0.045201
# 439             0                0            0.994809            0.005191
# 298             0                0            0.959132            0.040868
# 37              0                0            0.999397            0.000603
# 515             0                0            0.989876            0.010124
# 382             0                0            0.999489            0.000511
# 310             0                0            0.995708            0.004292
# 538             0                0            0.999196            0.000804
# 345             0                0            0.999900            0.000100

# %% [markdown]
# 📌 정확도

# %%
accuracy = accuracy_score(test_y, y_pred)
accuracy
# Out:
# 0.9736842105263158

# %% [markdown]
# 📌 그래프 구현 (countplot)

# %%
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties

# 폰트 설정
font_prop = FontProperties(fname="/System/Library/Fonts/Supplemental/AppleGothic.ttf", size=12)

# %%
sns.set_theme(style="darkgrid")

plt.figure()
sns.countplot(x=data['diagnosis'],
              palette=['pink', 'red'])
plt.xticks(ticks=[0,1], labels=["Benign (0)", "Malignant (1)"])
plt.xlabel("Diagnosis")
plt.ylabel("각 클래스의 샘플 수", fontproperties=font_prop)
plt.title("유방암 예측", fontproperties=font_prop)
# Out:
# /var/folders/0p/p1yx5lj17yx384d74tkfr6480000gn/T/ipykernel_12936/1808046602.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data['diagnosis'],
# Text(0.5, 1.0, '유방암 예측')

# %% [markdown]
# 📌 그래프 구현 (confusion_matrix)

# %%
conf_matrix = confusion_matrix(test_y, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='magma', xticklabels=['Benign (0)', 'Malignant (1)'], yticklabels=['Benign (0)', 'Malignant (1)'])
plt.xlabel("예측 Label", fontproperties=font_prop)
plt.ylabel("실제 Label", fontproperties=font_prop)
plt.title("Confusion Matrix by SVM")
plt.savefig('SVM_cm')
plt.show()
